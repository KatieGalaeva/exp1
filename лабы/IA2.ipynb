# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
train_path= pd.read_csv('IA2-train.csv')
test_path= pd.read_csv('IA2-dev.csv')
train_noisy_path= pd.read_csv('IA2-train-noisy.csv')
test_path
# Out:
#       dummy  Gender  Age  Driving_License  Previously_Insured  Vehicle_Damage  \
# 0         1       0   23                1                   1               0
# 1         1       1   40                1                   0               1
# 2         1       1   30                1                   0               1
# 3         1       1   25                1                   1               0
# 4         1       1   39                1                   0               1
# ...     ...     ...  ...              ...                 ...             ...
# 9995      1       0   23                1                   1               0
# 9996      1       1   32                1                   1               1
# 9997      1       1   49                1                   0               1
# 9998      1       0   23                1                   0               1
# 9999      1       0   25                1                   1               0
#
# ...

# %%
#You have one additional preprocessing step to do, which is to perform feature normalization (z-score) for 3 numerical features ("Age", "Annual_Premium", "Vintage").
train_path["Age"]=(train_path['Age']-train_path['Age'].mean())/train_path['Age'].std()
train_path["Vintage"]=(train_path['Vintage']-train_path['Vintage'].mean())/train_path['Vintage'].std()
train_path["Annual_Premium"]=(train_path['Annual_Premium']-train_path['Annual_Premium'].mean())/train_path['Annual_Premium'].std()
train_path
# Out:
#       dummy  Gender       Age  Driving_License  Previously_Insured  \
# 0         1       1 -1.171848                1                   0
# 1         1       0  0.242588                1                   0
# 2         1       0 -0.606074                1                   0
# 3         1       1  1.091249                1                   0
# 4         1       1 -0.606074                1                   0
# ...     ...     ...       ...              ...                 ...
# 5995      1       0  0.030422                1                   0
# 5996      1       1 -0.393909                1                   0
# 5997      1       0 -0.252465                1                   0
# 5998      1       0 -0.252465                1                   0
# 5999      1       1  1.869189                1                   0
#
#       Vehicle_Damage  Annual_Premium   Vintage  Region_Code_0  Region_Code_1  \
# 0                  1       -1.605168  0.382089              0              0
# ...

# %%
test_path["Age"]=(train_path['Age']-train_path['Age'].mean())/train_path['Age'].std()
test_path["Vintage"]=(train_path['Vintage']-train_path['Vintage'].mean())/train_path['Vintage'].std()
test_path["Annual_Premium"]=(train_path['Annual_Premium']-train_path['Annual_Premium'].mean())/train_path['Annual_Premium'].std()
test_path
# Out:
#       dummy  Gender       Age  Driving_License  Previously_Insured  \
# 0         1       0 -1.171848                1                   1
# 1         1       1  0.242588                1                   0
# 2         1       1 -0.606074                1                   0
# 3         1       1  1.091249                1                   1
# 4         1       1 -0.606074                1                   0
# ...     ...     ...       ...              ...                 ...
# 9995      1       0       NaN                1                   1
# 9996      1       1       NaN                1                   1
# 9997      1       1       NaN                1                   0
# 9998      1       0       NaN                1                   0
# 9999      1       0       NaN                1                   1
#
#       Vehicle_Damage  Annual_Premium   Vintage  Region_Code_0  Region_Code_1  \
# 0                  0       -1.605168  0.382089              0              0
# ...

# %%
train_noisy_path["Age"]=(train_path['Age']-train_path['Age'].mean())/train_path['Age'].std()
train_noisy_path["Vintage"]=(train_path['Vintage']-train_path['Vintage'].mean())/train_path['Vintage'].std()
train_noisy_path["Annual_Premium"]=(train_path['Annual_Premium']-train_path['Annual_Premium'].mean())/train_path['Annual_Premium'].std()
train_noisy_path
# Out:
#       dummy  Gender       Age  Driving_License  Previously_Insured  \
# 0         1       1 -1.171848                1                   0
# 1         1       0  0.242588                1                   0
# 2         1       0 -0.606074                1                   0
# 3         1       1  1.091249                1                   0
# 4         1       1 -0.606074                1                   0
# ...     ...     ...       ...              ...                 ...
# 5995      1       0  0.030422                1                   0
# 5996      1       1 -0.393909                1                   0
# 5997      1       0 -0.252465                1                   0
# 5998      1       0 -0.252465                1                   0
# 5999      1       1  1.869189                1                   0
#
#       Vehicle_Damage  Annual_Premium   Vintage  Region_Code_0  Region_Code_1  \
# 0                  1       -1.605168  0.382089              0              0
# ...

# %%
#Part 1 (35 pts) Logstic regression with L2 (Ridge) regularization
y_train=train_path['Response']
train_path_without_Res=train_path.drop(columns=['Response'])
y_test=test_path['Response']
test_path_without_Res=test_path.drop(columns=['Response'])
y_train_noisy=train_noisy_path['Response']
train_noisy_path_without_Res=train_noisy_path.drop(columns=['Response'])
test_path
# Out:
#       dummy  Gender       Age  Driving_License  Previously_Insured  \
# 0         1       0 -1.171848                1                   1
# 1         1       1  0.242588                1                   0
# 2         1       1 -0.606074                1                   0
# 3         1       1  1.091249                1                   1
# 4         1       1 -0.606074                1                   0
# ...     ...     ...       ...              ...                 ...
# 9995      1       0       NaN                1                   1
# 9996      1       1       NaN                1                   1
# 9997      1       1       NaN                1                   0
# 9998      1       0       NaN                1                   0
# 9999      1       0       NaN                1                   1
#
#       Vehicle_Damage  Annual_Premium   Vintage  Region_Code_0  Region_Code_1  \
# 0                  0       -1.605168  0.382089              0              0
# ...

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(train_path_without_Res,y_train)
y_pred=model.predict(test_path_without_Res)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       2 model = LogisticRegression()
#       3 model.fit(train_path_without_Res,y_train)
# ----> 4 y_pred=model.predict(test_path_without_Res)
#
# File c:\Users\Ekaterina\miniconda3\envs\mltest\Lib\site-packages\sklearn\linear_model\_base.py:351, in LinearClassifierMixin.predict(self, X)
#     337 """
#     338 Predict class labels for samples in X.
#     339
#    (...)
#     348     Vector containing the class labels for each sample.
#     349 """
#     350 xp, _ = get_namespace(X)
# --> 351 scores = self.decision_function(X)
#     352 if len(scores.shape) == 1:
#     353     indices = xp.astype(scores > 0, int)
#
# File c:\Users\Ekaterina\miniconda3\envs\mltest\Lib\site-packages\sklearn\linear_model\_base.py:332, in LinearClassifierMixin.decision_function(self, X)
#     329 check_is_fitted(self)
# ...

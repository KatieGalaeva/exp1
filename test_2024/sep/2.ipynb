# %%
def load_matrix():
    n = int(input())
    a = (input().split(' '))
    a_int=[int(el) for el in a]
    return a_int

def check(a_int):
    first = a_int[0]
    index = 0
    arr=[]
    if first!=-1:
        arr.append(first)
    else:
        first=1
        arr.append(first)
    for i in range(1, len(a_int)):
        if a_int[i]!=-1 and a_int[i]<=first:
            break
        if a_int[i]>first:
            if i-index==1:
                arr.append(a_int[i]-first)
            else:
                count=0
                for _ in range(i-index-1):
                    arr.append(1)
                    count+=1
                if a_int[i]-first-count>=1:
                    arr.append(a_int[i]-first-count)
                else:
                    break
            first=a_int[i]
            index=i
       
        if a_int[i]>first:
            first=a_int[i]
            index=i

    if a_int[-1]==-1:
        arr.append(1)
    
    if len(arr)==len(a_int):
        print('YES')
        return print(*arr)
    else:
        return print('NO')
    
a_int = load_matrix()
check(a_int)
# Out:
# NO

# %%
def load_matrix():
    n = int(input())
    a = (input().split(' '))
    a_int=[int(el) for el in a]
    return a_int

def check(a_int):
    first = a_int[0]
    index = 0
    
    neg_pref = 0
    if first == -1:
        first = 1
        neg_pref=1
    
    arr=[first]

    neg_cnt = 0
    for i in range(1, len(a_int)):
        if a_int[i] < 0:
            neg_cnt += 1
        else:
            neg_cnt = 0

        if a_int[i]!=-1 and a_int[i]<=first:
            #print('No')
            break

        if a_int[i]>first:
            if i-index==1:
                arr.append(a_int[i]-first)
            else:
                count=0
                for _ in range(i-index-1):
                    arr.append(1)
                    count+=1
                if a_int[i]-first-count>=1:
                    arr.append(a_int[i]-first-count)
                else:
                    #print('No')
                    break
            first=a_int[i]
            index=i

    if len(a_int) == neg_cnt + neg_pref:
        print('NO')
        return

    if len(a_int) - 1 - index == neg_cnt:
        for _ in range(neg_cnt):
            arr.append(1)

    elif a_int[-1]==-1:
        arr.append(1)
    #print('Yes')

    if len(arr)==len(a_int):
        print('YES')
        print(*arr)
    else:
        print('NO')
    

a_int = load_matrix()
check(a_int)

# %%
def load_matrix():
    n = int(input())
    a = (input().split(' '))
    a_int=[int(el) for el in a]
    return a_int

def check(a_int):
    first = a_int[0]
    index = 0
    
    if first == -1:
        first = 1
    
    arr=[first]

    neg_cnt = 0
    for i in range(1, len(a_int)):
        if a_int[i] < 0:
            neg_cnt += 1
        else:
            neg_cnt = 0

        if a_int[i]!=-1 and a_int[i]<=first:
            #print('No')
            break

        if a_int[i]>first:
            if i-index==1:
                arr.append(a_int[i]-first)
            else:
                count=0
                for _ in range(i-index-1):
                    arr.append(1)
                    count+=1
                if a_int[i]-first-count>=1:
                    arr.append(a_int[i]-first-count)
                else:
                    #print('No')
                    break
            first=a_int[i]
            index=i

    if len(a_int) - 1 - index == neg_cnt:
        for _ in range(neg_cnt):
            arr.append(1)

    elif a_int[-1]==-1:
        arr.append(1)
    #print('Yes')

    if len(arr)==len(a_int):
        print('YES')
        print(*arr)
    else:
        print('NO')
    

a_int = load_matrix()
check(a_int)
# Out:
# NO
